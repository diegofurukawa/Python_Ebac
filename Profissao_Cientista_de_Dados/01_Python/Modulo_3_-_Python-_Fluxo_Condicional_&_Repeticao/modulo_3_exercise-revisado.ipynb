# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Fluxo Condicional & Repetição
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Estrutura condicional if / else / elif;</li>
#   <li>Estrutura condicional try / catch / finally;</li>
#   <li>Estrutura de repetição for / in.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Estrutura condicional for / in

# %% [markdown]
# Na lista `propaganda_online` abaixo, estão presente os dados de usuários que acessaram um determinado site e se o mesmo clicou em uma propaganda.

# %%
propaganda_online = [
  {'tempo_gasto_site': 68.95, 'idade': 35, 'renda_area': 61833.90, 'tempo_gasto_internet': 256.09, 'cidade': 'Wrightburgh', 'pais': 'Tunisia', 'clicou_no_ad': 0},
  {'tempo_gasto_site': 80.23, 'idade': 31, 'renda_area': 68441.85, 'tempo_gasto_internet': 193.77, 'cidade': 'West Jodi', 'pais': 'Nauru', 'clicou_no_ad': 0},
  {'tempo_gasto_site': 69.47, 'idade': 26, 'renda_area': 59785.94, 'tempo_gasto_internet': 236.50, 'cidade': 'Davidton', 'pais': 'San Marino', 'clicou_no_ad': 0},
  {'tempo_gasto_site': 68.37, 'idade': 35, 'renda_area': 73889.99, 'tempo_gasto_internet': 225.58, 'cidade': 'South Manuel', 'pais': 'Iceland', 'clicou_no_ad': 0},
  {'tempo_gasto_site': 88.91, 'idade': 33, 'renda_area': 53852.85, 'tempo_gasto_internet': 208.36, 'cidade': 'Brandonstad', 'pais': 'Myanmar', 'clicou_no_ad': 0},
  {'tempo_gasto_site': None, 'idade': 48, 'renda_area': 24593.33, 'tempo_gasto_internet': 131.76, 'cidade': 'Port Jefferybury', 'pais': 'Australia', 'clicou_no_ad': 1},
  {'tempo_gasto_site': 74.53, 'idade': 30, 'renda_area': 68862.00, 'tempo_gasto_internet': 221.51, 'cidade': 'West Colin', 'pais': 'Grenada'},
  {'tempo_gasto_site': 69.88, 'idade': 20, 'renda_area': 55642.32, 'tempo_gasto_internet': 183.82, 'cidade': 'Ramirezton', 'pais': 'Ghana', 'clicou_no_ad': 0}
]

# %%
for dado_de_usuario in propaganda_online:
  print(dado_de_usuario)
# Out:
# {'tempo_gasto_site': 68.95, 'idade': 35, 'renda_area': 61833.9, 'tempo_gasto_internet': 256.09, 'cidade': 'Wrightburgh', 'pais': 'Tunisia', 'clicou_no_ad': 0}
# {'tempo_gasto_site': 80.23, 'idade': 31, 'renda_area': 68441.85, 'tempo_gasto_internet': 193.77, 'cidade': 'West Jodi', 'pais': 'Nauru', 'clicou_no_ad': 0}
# {'tempo_gasto_site': 69.47, 'idade': 26, 'renda_area': 59785.94, 'tempo_gasto_internet': 236.5, 'cidade': 'Davidton', 'pais': 'San Marino', 'clicou_no_ad': 0}
# {'tempo_gasto_site': 68.37, 'idade': 35, 'renda_area': 73889.99, 'tempo_gasto_internet': 225.58, 'cidade': 'South Manuel', 'pais': 'Iceland', 'clicou_no_ad': 0}
# {'tempo_gasto_site': 88.91, 'idade': 33, 'renda_area': 53852.85, 'tempo_gasto_internet': 208.36, 'cidade': 'Brandonstad', 'pais': 'Myanmar', 'clicou_no_ad': 0}
# {'tempo_gasto_site': None, 'idade': 48, 'renda_area': 24593.33, 'tempo_gasto_internet': 131.76, 'cidade': 'Port Jefferybury', 'pais': 'Australia', 'clicou_no_ad': 1}
# {'tempo_gasto_site': 74.53, 'idade': 30, 'renda_area': 68862.0, 'tempo_gasto_internet': 221.51, 'cidade': 'West Colin', 'pais': 'Grenada'}
# {'tempo_gasto_site': 69.88, 'idade': 20, 'renda_area': 55642.32, 'tempo_gasto_internet': 183.82, 'cidade': 'Ramirezton', 'pais': 'Ghana', 'clicou_no_ad': 0}

# %% [markdown]
# 1.1. Imprime os seguintes valores da lista:
# `tempo_gasto_site` e `idade`
#
# Dica: Utilize os conceitos de chave e valor de elementos de uma lista para selecionar os valores de uma chave (lista[chave]), conforme exemplo abaixo, na qual imprime somente os dados da chave `cidade`:

# %%
for dado_de_usuario in propaganda_online:
    print(dado_de_usuario['cidade'])
# Out:
# Wrightburgh
# West Jodi
# Davidton
# South Manuel
# Brandonstad
# Port Jefferybury
# West Colin
# Ramirezton

# %%
for dado_de_usuario in propaganda_online:
    # Imprimindo 1 a 1
    print(dado_de_usuario['tempo_gasto_site'])
    print(dado_de_usuario['idade'])

    # Imprimindo em Texto
    print(f'O tempo gasto foi de {dado_de_usuario["tempo_gasto_site"]}, e a idade é {dado_de_usuario["idade"]}.')
    print('\n')
# Out:
# 68.95
# 35
# O tempo gasto foi de 68.95, e a idade é 35.
#
#
# 80.23
# 31
# O tempo gasto foi de 80.23, e a idade é 31.
#
#
# 69.47
# 26
# O tempo gasto foi de 69.47, e a idade é 26.
#
#
# 68.37
# 35
# O tempo gasto foi de 68.37, e a idade é 35.
#
#
# 88.91
# 33
# O tempo gasto foi de 88.91, e a idade é 33.
#
#
# None
# 48
# O tempo gasto foi de None, e a idade é 48.
#
#
# 74.53
# 30
# O tempo gasto foi de 74.53, e a idade é 30.
#
#
# 69.88
# 20
# O tempo gasto foi de 69.88, e a idade é 20.

# %% [markdown]
# Extrair os valores da chave tempo_gasto_site

# %%
for dado_de_usuario in propaganda_online:
    # Imprimindo 1 a 1
    print(dado_de_usuario['tempo_gasto_site'])
    print('\n')
# Out:
# 68.95
#
#
# 80.23
#
#
# 69.47
#
#
# 68.37
#
#
# 88.91
#
#
# None
#
#
# 74.53
#
#
# 69.88

# %% [markdown]
# Extrair os valores da chave idade

# %%
for dado_de_usuario in propaganda_online:
    # Imprimindo 1 a 1
    print(dado_de_usuario['idade'])
    print('\n')
# Out:
# 35
#
#
# 31
#
#
# 26
#
#
# 35
#
#
# 33
#
#
# 48
#
#
# 30
#
#
# 20

# %% [markdown]
# ## 2\. Estrutura condicional if / else

# %% [markdown]
# 2.1. Utilize a estrutura if/else para imprimir a cidade dos usuários que gastaram mais de 100 horas de tempo na internet
#
# Dica: Após a iteração dos elementos da lista (Através da estrutura condicional FOR),  utilize a estrutura if/else para criar a condição dos valores da chave `tempo_gasto_internet`

# %%
for dado_de_usuario in propaganda_online:
  if dado_de_usuario['tempo_gasto_internet'] > 100:
    # Imprimindo em Texto
    print(f'O usuário gastou {dado_de_usuario["tempo_gasto_internet"]} horas na internet e é da cidade de {dado_de_usuario["cidade"]}.')
    print('\n')
  else:
    print()
# Out:
# O usuário gastou 256.09 horas na internet e é da cidade de Wrightburgh.
#
#
# O usuário gastou 193.77 horas na internet e é da cidade de West Jodi.
#
#
# O usuário gastou 236.5 horas na internet e é da cidade de Davidton.
#
#
# O usuário gastou 225.58 horas na internet e é da cidade de South Manuel.
#
#
# O usuário gastou 208.36 horas na internet e é da cidade de Brandonstad.
#
#
# O usuário gastou 131.76 horas na internet e é da cidade de Port Jefferybury.
#
#
# O usuário gastou 221.51 horas na internet e é da cidade de West Colin.
#
#
# O usuário gastou 183.82 horas na internet e é da cidade de Ramirezton.

# %% [markdown]
# ## 3\. Estrutura condicional try / except

# %% [markdown]
# 3.1. Utilize a estrutura try/except para imprimir as cidades dos usuários que passaram mais de 70 segundos no site.
#
# Dica: Realize o tratamento de exceções dentro da execução da iteração dos elementos da lista

# %%
for dado_de_usuario in propaganda_online:
    try:
      if ((dado_de_usuario['tempo_gasto_internet']) * 60) > 70:
        # Imprimindo em Texto
        print(f'O usuário gastou {dado_de_usuario["tempo_gasto_internet"]} horas na internet e é da cidade de {dado_de_usuario["cidade"]}.')
        print('\n')
      else:
        print(f'O usuário NÃO gastou O TEMPO necessário e é da cidade de {dado_de_usuario["cidade"]}.')
        print('\n')
    except:
      print('Não tratado')
# Out:
# O usuário gastou 256.09 horas na internet e é da cidade de Wrightburgh.
#
#
# O usuário gastou 193.77 horas na internet e é da cidade de West Jodi.
#
#
# O usuário gastou 236.5 horas na internet e é da cidade de Davidton.
#
#
# O usuário gastou 225.58 horas na internet e é da cidade de South Manuel.
#
#
# O usuário gastou 208.36 horas na internet e é da cidade de Brandonstad.
#
#
# O usuário gastou 131.76 horas na internet e é da cidade de Port Jefferybury.
#
#
# O usuário gastou 221.51 horas na internet e é da cidade de West Colin.
#
#
# O usuário gastou 183.82 horas na internet e é da cidade de Ramirezton.

# %% [markdown]
# # Exercício bônus

# %% [markdown]
# ## 1\. Dados de interação de usuários com propagandas online

# %% [markdown]
# 1.1. Crie uma lista chamada `paises` com o pais dos usuários com mais de 30 anos.
#
# Dica: Para armazenar os países dos usuários na lista `paises` utilize o método append().

# %%
paises = []
for dado_de_usuario in propaganda_online:
  ...

print(paises)
# Out:
# []

# %% [markdown]
# ---

# %% [markdown]
# 1.2. Crie uma lista chamada `leads` com a renda dos usuários que clicaram na propaganda.
#
# Dica: Para armazenar a renda dos usuários na lista `leads` utilize o método append().

# %%
leads = []

for dado_de_usuario in propaganda_online:
  ...

print(leads)
# Out:
# []

# %% [markdown]
# ---
